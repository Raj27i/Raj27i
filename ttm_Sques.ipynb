# %%
import os
import pandas as pd 
import pandas_ta as ta

# %%
for filename in os.listdir('Datasets'):
    symbol = filename.split('.')[0]+".NS"
    #print(symbol)
    
    df = pd.read_csv('Datasets/{}'.format(filename))    
    df = df.dropna(subset=['close'])    
    df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-02-01  434.100006  444.500000  430.850006  435.450012  431.427368
# 1   2023-02-02  434.000000  440.950012  430.600006  432.850006  428.851379
# 2   2023-02-03  433.950012  442.000000  426.600006  434.649994  430.634735
# 3   2023-02-06  452.000000  476.500000  446.950012  470.149994  465.806793
# 4   2023-02-07  470.200012  480.700012  469.000000  479.450012  475.020905
# 5   2023-02-08  480.149994  482.250000  468.450012  474.000000  469.621246
# 6   2023-02-09  469.700012  480.500000  469.000000  474.399994  470.017548
# 7   2023-02-10  473.500000  477.450012  471.750000  473.500000  469.125854
# 8   2023-02-13  476.850006  476.850006  466.149994  471.450012  467.094818
# 9   2023-02-14  473.799988  474.899994  467.750000  473.049988  468.679993
# 10  2023-02-15  470.799988  474.700012  465.899994  469.299988  464.964661
# ...
