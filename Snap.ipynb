# %%
import os
import pandas as pd
import yfinance as yf
import pandas_ta as ta

# %%
data = yf.download('ITC.NS',start='2024-03-10',end='2024-04-10')
excel_file = r'C:\Users\durr\OneDrive - COWI\Desktop\TTM_Suess\Datasets\control.xlsx'
#data.to_csv('datasets/covid_dataset.csv', encoding='utf-8')
data.to_excel(excel_file, index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
with open('symbols.csv') as f:
    lines = f.read().splitlines()
for symbol in lines:
    data = yf.download(symbol, start="2024-02-01", end="2024-04-10")
    try:data.to_csv('Datasets/{}.csv'.format(symbol))
        
    except Exception as e:
        print(f"An error occurred with symbol {symbol}: {e}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...
